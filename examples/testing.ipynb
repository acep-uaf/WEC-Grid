# %%
import marinegrid

# %%
example = marinegrid.Study()
example
# Out:
# Study:
# ├─ Case: Not Set
# ├─ Case File: Not Set
# ├─ Loaded Modelers: None
# └─ Time: Time:
# ├─ Start: 2026-02-04 00:00:00
# ├─ End: 2026-02-04 23:55:00
# ├─ Steps: 288
# ├─ Duration: 23:55:00
# └─ Frequency: 5min

# %%
example.set_case(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 example.set_case(4)
#
# File ~/research/code/refactor/Marine-Grid/src/marinegrid/study.py:90, in Study.set_case(self, case_file)
#      76 """
#      77 Normalize and validate a power system case file path.
#      78
#    (...)     85     ValueError: If the file extension is not allowed.
#      86 """
#      87 # if not isinstance(case_file, (str, Path)):
#      88 #     raise TypeError("case_file must be a str or pathlib.Path")
# ---> 90 path = Path(case_file).expanduser().resolve()
#      92 if not path.exists():
#      93     raise FileNotFoundError(f"Case file not found: {path}")
#
# File ~/miniconda3/envs/marinegrid/lib/python3.12/pathlib.py:1162, in Path.__init__(self, *args, **kwargs)
#    1159     msg = ("support for supplying keyword arguments to pathlib.PurePath "
# ...
